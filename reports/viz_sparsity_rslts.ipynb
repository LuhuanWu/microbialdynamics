# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mlp_obs02_c = np.array([[0.99718805, 0.42474186, 0.40252447, 0.39318025, 0.38670045, 0.38579279],
 [0.99573132, 0.34815931, 0.33381224, 0.32693893, 0.32028782, 0.32011646]])

mlp_obs02_p = np.array([[0.99662192, 0.34598744, 0.33005661, 0.32267797, 0.31528902, 0.31485158],
 [0.99548816, 0.28200686, 0.26570868, 0.26861221, 0.2625438,  0.25829142]])
 
mlp_obs02_logp = np.array([[ 0.9805622,   0.03411096,  0.00496328, -0.00448048, -0.00891149, -0.00704169],
 [ 0.97496869,  0.01119745, -0.01186574, -0.03151,    -0.02183056, -0.04187405]])
 

clv_obs02_c = np.array([[0.97915696, 0.68103671, 0.55786702, 0.45905828, 0.3542245,  0.26193684],
 [0.97133733, 0.59726754, 0.4498384,  0.38122052, 0.29114503, 0.21359783]])

clv_obs02_p = np.array([[0.97405445, 0.63709813, 0.50842905, 0.39656943, 0.28423923, 0.18216521],
 [0.97086896, 0.58318505, 0.43735355, 0.33600056, 0.23192573, 0.12539321]])

clv_obs02_logp = np.array([[ 0.93006152,  0.4490062,   0.28200817,  0.16090173,  0.05503094, -0.02973545],
 [ 0.93754333,  0.4430185,   0.26578408,  0.135001,    0.04548353, -0.06054282]])


clv_original_obs02_c = np.array([[0.99334553, 0.72401899, 0.62440524, 0.55157608, 0.48066241, 0.41442293],
 [0.98890096, 0.6536893,  0.54335523, 0.51052904, 0.45131236, 0.38073504]])

clv_original_obs02_p = np.array([[0.99161068, 0.6824986,  0.57990515, 0.49427074, 0.41059625, 0.33663869],
 [0.98928246, 0.61138561, 0.49916434, 0.43599623, 0.36298281, 0.28578162]])

clv_original_obs02_logp = np.array([[ 0.95498889,  0.49275678,  0.31818295,  0.19409972,  0.08850408, -0.00132847],
 [ 0.94570899,  0.48227143,  0.29874098,  0.15937513,  0.06524771, -0.03629923]])


linear_obs02_c = np.array([[0.98997581, 0.68828812, 0.5986211,  0.54965475, 0.50772306, 0.47992909],
 [0.98470088, 0.60981968, 0.51324126, 0.47795343, 0.42954737, 0.40078133]])

linear_obs02_p = np.array([[0.9873364,  0.6464988,  0.5509629,  0.49457729, 0.44896322, 0.41396385],
 [0.98474771, 0.59367713, 0.48513025, 0.425008,   0.37224638, 0.33484906]])

linear_obs02_logp = np.array([[0.93893431, 0.39735204, 0.22957814, 0.13355476, 0.06269217, 0.00961936],
 [ 0.92843635,  0.36821222,  0.19401705,  0.07952154,  0.01636451, -0.058061  ]])

# %%
mlp_obs04_c = np.array([[0.9907537,  0.59992769, 0.56669864, 0.54279399, 0.52215201, 0.507402  ],
 [0.98707431, 0.50162378, 0.46853399, 0.44929624, 0.43124098, 0.41668159]])

mlp_obs04_p = np.array([[0.98878914, 0.54843903, 0.51313788, 0.48474109, 0.46401626, 0.44536859],
 [0.98628948, 0.49542534, 0.46408689, 0.43003964, 0.41126829, 0.39802605]])

mlp_obs04_logp = np.array([[0.94733654, 0.36167276, 0.28679407, 0.23298472, 0.19427329, 0.16099346],
 [0.93787125, 0.29869419, 0.21726298, 0.14532602, 0.09443867, 0.05692261]])


clv_obs04_c = np.array([[0.99667264, 0.71460816, 0.58456925, 0.4725076,  0.38411242, 0.30732059],
 [0.99555992, 0.67225131, 0.54561409, 0.437253,   0.34808487, 0.27664876]])

clv_obs04_p = np.array([[0.99557242, 0.68902668, 0.54097953, 0.41895926, 0.32204902, 0.23582315],
 [0.99504537, 0.69239676, 0.5333629,  0.39069384, 0.28735071, 0.19910997]])


clv_obs04_logp = np.array([[ 0.96946983,  0.61099499,  0.40109211,  0.23033339,  0.09881091, -0.01418626],
 [ 0.95913558,  0.58267626,  0.35617137,  0.16682613,  0.00923741, -0.10255957]])


clv_original_obs04_c = np.array([[0.97995286, 0.71192071, 0.58601946, 0.47025591, 0.37514246, 0.29336816],
 [0.98247236, 0.65011936, 0.52952281, 0.42718518, 0.34172916, 0.27036434]])

clv_original_obs04_p = np.array([[0.97597628, 0.68039691, 0.53891593, 0.41624683, 0.3127569,  0.2209453 ],
 [0.97541621, 0.68129757, 0.53230393, 0.39103472, 0.28439116, 0.19783843]])

clv_original_obs04_logp = np.array([[ 0.93708712,  0.56117776,  0.3646099,   0.20532864,  0.07892889, -0.03138578],
 [ 0.9332891,   0.53682226,  0.3117761,   0.11889917, -0.03443313, -0.13431716]])

linear_obs04_c = np.array([[0.98396555, 0.70308051, 0.60478023, 0.54351705, 0.50484982, 0.46923244],
 [0.97676444, 0.6659241,  0.54884779, 0.47138613, 0.43375367, 0.40265727]])

linear_obs04_p = np.array([[0.98246991, 0.66986781, 0.55567566, 0.4892121,  0.44835007, 0.41258651],
 [0.97467263, 0.67818907, 0.55812335, 0.46827954, 0.41913182, 0.38719612]])

linear_obs04_logp = np.array([[0.92088821, 0.52287471, 0.34895307, 0.24088085, 0.1682474,  0.10445523],
 [0.91707154, 0.50379133, 0.31424069, 0.17727172, 0.08230895, 0.02055335]])

# %%
mlp_obs06_c = np.array([[0.99857776, 0.68316907, 0.59891453, 0.55769148, 0.52920467, 0.50714591],
 [0.99812496, 0.72912875, 0.63810655, 0.58512771, 0.54905713, 0.51477113]])

mlp_obs06_p = np.array([[0.99818423, 0.65095562, 0.56275532, 0.51278865, 0.48044497, 0.4606185 ],
 [0.99745531, 0.65324631, 0.55429292, 0.49683088, 0.46327782, 0.43916351]])

mlp_obs06_logp = np.array([[0.98595216, 0.57913765, 0.4631806, 0.39215708, 0.3445121,  0.31613636],
 [0.98166393, 0.57128906, 0.43836844, 0.35446721, 0.30548191, 0.27052546]])

clv_obs06_c = np.array([[0.99698511, 0.69549415, 0.54670751, 0.42891705, 0.3320744,  0.25464511],
 [0.99517263, 0.73844254, 0.59481943, 0.4605248,  0.36771268, 0.26898783]])

clv_obs06_p = np.array([[0.99637714, 0.65746704, 0.49233526, 0.35384858, 0.23820758, 0.14350832],
 [0.99433751, 0.67408058, 0.51016185, 0.38257664, 0.28216588, 0.18243003]])

clv_obs06_logp = np.array([[ 0.97718251,  0.53912911,  0.2951048,   0.10814321, -0.03260422, -0.13819587],
 [ 0.9690559,   0.51717889,  0.24394768,  0.04532838, -0.10607922, -0.22725439]])

clv_original_obs06_c = np.array([[0.9508756,  0.6871098,  0.53429648, 0.40471476, 0.31110394, 0.24066681],
 [0.9612758,  0.73515764, 0.59111282, 0.47616971, 0.37649149, 0.28480011]])

clv_original_obs06_p = np.array([[0.94028486, 0.64860752, 0.48138827, 0.33496964, 0.22427189, 0.13039058],
 [0.94955618, 0.6709134,  0.50696233, 0.38837957, 0.28999698, 0.19488943]])

clv_original_obs06_logp = np.array([[ 0.87549317,  0.53564665,  0.33178449,  0.16671783,  0.03626078, -0.06267202],
 [ 0.87637734,  0.53590146,  0.32789838,  0.17575878,  0.05145466, -0.06602597]])


linear_obs06_c = np.array([[0.98979834, 0.71300346, 0.5964075,  0.52767989, 0.48769283, 0.4610678 ],
 [0.98258888, 0.76454842, 0.64773542, 0.57298616, 0.528303,   0.4833011 ]])

linear_obs06_p = np.array([[0.98855047, 0.6842719,  0.55879873, 0.4789176,  0.43127543, 0.40172929],
 [0.97842215, 0.6943101,  0.55911979, 0.48273838, 0.43713635, 0.40066087]])

linear_obs06_logp = np.array([[0.94826267, 0.59216103, 0.42035747, 0.3016116,  0.21737075, 0.15936667],
 [0.93826645, 0.58052081, 0.40018821, 0.28013456, 0.19657189, 0.13090825]])

# %%
# 20%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 20%, training")
plt.plot(mlp_obs02_c[0], label='mlp');
plt.plot(clv_obs02_c[0], label='clv');
plt.plot(clv_original_obs02_c[0], label='clv_original');
plt.plot(linear_obs02_c[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 20%, validation")
plt.plot(mlp_obs02_c[1], label='mlp');
plt.plot(clv_obs02_c[1], label='clv');
plt.plot(clv_original_obs02_c[1], label='clv_original');
plt.plot(linear_obs02_c[1], label='linear');
plt.legend()
plt.xlabel("k-steps");

# %%
# 20%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 20%, training")
plt.plot(mlp_obs02_p[0], label='mlp');
plt.plot(clv_obs02_p[0], label='clv');
plt.plot(clv_original_obs02_p[0], label='clv_original');
plt.plot(linear_obs02_p[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 20%, validation")
plt.plot(mlp_obs02_p[1], label='mlp');
plt.plot(clv_obs02_p[1], label='clv');
plt.plot(clv_original_obs02_p[1], label='clv_original');
plt.plot(linear_obs02_p[1], label='linear');
plt.legend()
plt.xlabel("k-steps")
# Out:
# Text(0.5, 0, 'k-steps')

# %%
# 40%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 40%, training")
plt.plot(mlp_obs04_c[0], label='mlp');
plt.plot(clv_obs04_c[0], label='clv');
plt.plot(clv_original_obs04_c[0], label='clv_original');
plt.plot(linear_obs04_c[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 40%, validation")
plt.plot(mlp_obs04_c[1], label='mlp');
plt.plot(clv_obs04_c[1], label='clv');
plt.plot(clv_original_obs04_c[1], label='clv_original');
plt.plot(linear_obs04_c[1], label='linear');
plt.legend()
plt.xlabel("k-steps");

# %%
# 40%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 40%, training")
plt.plot(mlp_obs04_p[0], label='mlp');
plt.plot(clv_obs04_p[0], label='clv');
plt.plot(clv_original_obs04_p[0], label='clv_original');
plt.plot(linear_obs04_p[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 40%, validation")
plt.plot(mlp_obs04_p[1], label='mlp');
plt.plot(clv_obs04_p[1], label='clv');
plt.plot(clv_original_obs04_p[1], label='clv_original');
plt.plot(linear_obs04_p[1], label='linear');
plt.legend()
plt.xlabel("k-steps")
# Out:
# Text(0.5, 0, 'k-steps')

# %%
# 60%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 60%, training")
plt.plot(mlp_obs06_c[0], label='mlp');
plt.plot(clv_obs06_c[0], label='clv');
plt.plot(clv_original_obs06_c[0], label='clv_original');
plt.plot(linear_obs06_c[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 60%, validation")
plt.plot(mlp_obs06_c[1], label='mlp');
plt.plot(clv_obs06_c[1], label='clv');
plt.plot(clv_original_obs06_c[1], label='clv_original');
plt.plot(linear_obs06_c[1], label='linear');
plt.legend()
plt.xlabel("k-steps")
# Out:
# Text(0.5, 0, 'k-steps')

# %%
# 60%

plt.figure(figsize=(10, 4))

plt.subplot(1,2,1)
plt.title("observation percentage = 60%, training")
plt.plot(mlp_obs06_p[0], label='mlp');
plt.plot(clv_obs06_p[0], label='clv');
plt.plot(clv_original_obs06_p[0], label='clv_original');
plt.plot(linear_obs06_p[0], label='linear');
plt.legend()
plt.xlabel("k-steps")

plt.subplot(1,2,2)
plt.title("observation percentage = 60%, validation")
plt.plot(mlp_obs06_p[1], label='mlp');
plt.plot(clv_obs06_p[1], label='clv');
plt.plot(clv_original_obs06_p[1], label='clv_original');
plt.plot(linear_obs06_p[1], label='linear');
plt.legend()
plt.xlabel("k-steps")
# Out:
# Text(0.5, 0, 'k-steps')

# %%
plt.figure(figsize=(20,8))

plt.subplot(2,4,1)
plt.title("mlp (training)")
plt.plot(mlp_obs02_p[0], label='20%')
plt.plot(mlp_obs04_p[0], label='40%')
plt.plot(mlp_obs06_p[0], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,2)
plt.title("clv (training)")
plt.plot(clv_obs02_p[0], label='20%')
plt.plot(clv_obs04_p[0], label='40%')
plt.plot(clv_obs06_p[0], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,3)
plt.title("clv original (training)")
plt.plot(clv_original_obs02_p[0], label='20%')
plt.plot(clv_original_obs04_p[0], label='40%')
plt.plot(clv_original_obs06_p[0], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,4)
plt.title("linear (training)")
plt.plot(linear_obs02_p[0], label='20%')
plt.plot(linear_obs04_p[0], label='40%')
plt.plot(linear_obs06_p[0], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,5)
plt.title("mlp (validation)")
plt.plot(mlp_obs02_p[1], label='20%')
plt.plot(mlp_obs04_p[1], label='40%')
plt.plot(mlp_obs06_p[1], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,6)
plt.title("clv (validation)")
plt.plot(clv_obs02_p[1], label='20%')
plt.plot(clv_obs04_p[1], label='40%')
plt.plot(clv_obs06_p[1], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,7)
plt.title("clv original (validation)")
plt.plot(clv_original_obs02_p[1], label='20%')
plt.plot(clv_original_obs04_p[1], label='40%')
plt.plot(clv_original_obs06_p[1], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.subplot(2,4,8)
plt.title("linear (validation)")
plt.plot(linear_obs02_p[1], label='20%')
plt.plot(linear_obs04_p[1], label='40%')
plt.plot(linear_obs06_p[1], label='60%')
plt.ylim(0,1)
plt.legend()
plt.xlabel("k-step")

plt.tight_layout()
