# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
general_dir = "/Users/leah/Columbia/courses/19summer/microbialdynamics/src/rslts/1001_test_mlp/clv_count_Dx_10_obs_02s/D191002_003154_7839_np_32_lr_0.005_epochs_[20, 50, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 500]_seed_0/"

ck1_dir = general_dir + "checkpoint_1/test_obs_y_hat_bar_plots/"
ck2_dir = general_dir + "checkpoint_2/test_obs_y_hat_bar_plots/"
ck3_dir = general_dir + "checkpoint_3/test_obs_y_hat_bar_plots/"
ck4_dir = general_dir + "checkpoint_4/test_obs_y_hat_bar_plots/"
ck5_dir = general_dir + "checkpoint_5/test_obs_y_hat_bar_plots/"

# %%
img = mpimg.imread(ck1_dir + "obs_idx_0_1_step.png")
imgplot = plt.imshow(img)

# %%
def plot_rslt(ck):
    plt.figure(figsize=(20,30))
    i = 1
    for k in range(3):
        plt.subplot(1,3,i)

        img = mpimg.imread(general_dir + "checkpoint_{}/test_obs_y_hat_bar_plots/obs_idx_0_{}_step.png".format(ck,k))
        plt.imshow(img)

        i += 1

# %%
plot_rslt(1)

# %%
plot_rslt(2)

# %%
plot_rslt(3)

# %%
plot_rslt(4)

# %%
plot_rslt(5)

# %%
plot_rslt(6)

# %%
plot_rslt(7)

# %%
plot_rslt(9)
